# %% [markdown]
# # Parameters determination
# use the folder 2026-01-28 broad measurements

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
import Methods as m
import importlib
importlib.reload(m)
# Out:
# <module 'Methods' from '/Users/markzhitnitsky/Desktop/School/2025-26 Year/PHYS409/Experiment 1 - PET/Code/Methods.py'>

# %%
x0 = -0.6 # mm
Rscint = 35 # mm
Rsource = 1.1 # mm
alpha = 0.012
amplitude = 0.006
L = 36 # mm
collection_time = 65 # s


Xarr = np.arange(start=-Rscint * 1.5 + x0,stop=Rscint * 1.5 + x0,step=0.05)
convolvedSignal = m.doubleSlitModelConvoluted(Xarr, 0,Rscint,Rsource,alpha,amplitude,x0, L,collection_time)
dist_array, counts_array, ucounts_array = m.readLineScan("./data/2026-01-28 broad measurements/Jan 28, 2026, 3_52 PM, Scan1, 0_0 Deg, copper.dat")

print(max(convolvedSignal))

m.displayModelDataLinescan(Xarr, convolvedSignal, dist_array, counts_array, ucounts_array, "Combined Convoluted Model+Residual - only copper.png")
# Out:
# 29.47528413155637

# %%
x0 = -1.3 # mm
Rscint = 35 # mm
Rsource = 1.1 # mm
alpha = 0.003
amplitude = 0.024
L = 36 # mm
collection_time = 15 # s
Wslit = 10# mm


Xarr = np.arange(start=-Rscint * 1.5 + x0,stop=Rscint * 1.5 + x0,step=0.05)
convolvedSignal = m.doubleSlitModelConvoluted(Xarr,Wslit,Rscint,Rsource,alpha,amplitude,x0, L,collection_time)
dist_array, counts_array, ucounts_array = m.readLineScan("./data/2026-01-28 broad measurements/Jan 28, 2026, 4_38 PM, Scan1, 0_0 Deg, nothing.dat")

print(max(convolvedSignal))

m.displayModelDataLinescan(Xarr, convolvedSignal, dist_array, counts_array, ucounts_array, "Combined Convoluted Model+Residual - open slit.png")
# Out:
# 361.6999373265307

# %%
x0 = -1.3 # mm
Rscint = 35 # mm
Rsource = 1.1 # mm
alpha = 0
amplitude = 0.006
L = 36 # mm
collection_time = 2400 # s
Wslit = 0# mm


Xarr = np.arange(start=-Rscint * 1.5 + x0,stop=Rscint * 1.5 + x0,step=0.05)
convolvedSignal = m.doubleSlitModelConvoluted(Xarr,Wslit,Rscint,Rsource,alpha,amplitude,x0, L,collection_time)
dist_array, counts_array, ucounts_array = m.readLineScan("./data/2026-01-28 broad measurements/Jan 30, 2026, 9_57 AM, Scan1, 0_0 Deg, lead+copper.dat")

print(max(convolvedSignal))

m.displayModelDataLinescan(Xarr, convolvedSignal, dist_array, counts_array, ucounts_array, "Combined Convoluted Model+Residual - open slit.png")
# Out:
# 56.622950819672134

# %% [markdown]
# ### Feb 4
# new linescans

# %%
x0 = -0.6 # mm
Rscint = 35 # mm
Rsource = 1.1 # mm
alpha = 0.012
amplitude = 0.006
L = 36 # mm
collection_time = 65 # s


Xarr = np.arange(start=-Rscint * 1.5 + x0,stop=Rscint * 1.5 + x0,step=0.05)
convolvedSignal = m.doubleSlitModelConvoluted(Xarr, 0,Rscint,Rsource,alpha,amplitude,x0, L,collection_time)
dist_array, counts_array, ucounts_array = m.readLineScan("./data/2026-01-28 broad measurements/Jan 28, 2026, 3_52 PM, Scan1, 0_0 Deg, copper.dat")

print(max(convolvedSignal))

m.displayModelDataLinescan(Xarr, convolvedSignal, dist_array, counts_array, ucounts_array, "Combined Convoluted Model+Residual - only copper.png")
